# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("chess - chess tempo openings database.csv")

# %%
df
# Out:
#                                                 Opening  Colour  Num Games  \
# 0                    Alekhine Defense, Balogh Variation     NaN        692
# 1                  Alekhine Defense, Brooklyn Variation     NaN        228
# 2                  Alekhine Defense, Exchange Variation     NaN       6485
# 3                   Alekhine Defense, Four Pawns Attack     NaN        881
# 4     Alekhine Defense, Four Pawns Attack, Fianchett...     NaN        259
# 5        Alekhine Defense, Four Pawns Attack, Main Line     NaN       1207
# 6     Alekhine Defense, Four Pawns Attack, Trifunovi...     NaN        323
# 7                             Alekhine Defense, General     NaN        524
# 8     Alekhine Defense, Hunt Variation, Lasker Simul...     NaN        334
# 9                   Alekhine Defense, Maroczy Variation     NaN        931
# 10                   Alekhine Defense, Modern Variation     NaN        501
# ...

# %%
moves_list = df['Moves']

# %%
df['moves_list']=moves_list.str.split(" ")

# %%
df['move1w'] = df['moves_list'].apply(lambda x : x[0] )

# %%
df['move1b'] = df['moves_list'].apply(lambda x : x[1] if len(x)>=2 else "" )

# %%
df['move2w'] = df['moves_list'].apply(lambda x : x[2] if len(x)>=3 else "" )

# %%
df['move2b'] = df['moves_list'].apply(lambda x : x[3] if len(x)>=4 else "" )

# %%
df['move3w'] = df['moves_list'].apply(lambda x : x[4] if len(x)>=5 else "" )
df['move3b'] = df['moves_list'].apply(lambda x : x[5] if len(x)>=6 else "" )
df['move4w'] = df['moves_list'].apply(lambda x : x[4] if len(x)>=7 else "" )
df['move4b'] = df['moves_list'].apply(lambda x : x[5] if len(x)>=8 else "" )

# %%
df['Colour'] = df['moves_list'].apply(lambda x : "white" if len(x)%2==1 else "black")

# %%
 float(df["Player Win %"][0][:-1])
# Out:
# 40.8

# %%
df["Player Win %"] = df["Player Win %"].apply(lambda x : float(x[:-1] ))

# %%
df["Opponent Win %"] = df["Opponent Win %"].apply(lambda x : float(x[:-1]) )
df["Draw %"] = df["Draw %"].apply(lambda x : float(x[:-1] ))

# %%
df['not_lose %'] = (df["Draw %"] + df["Player Win %"])

# %%
df.groupby('move1w').agg({"Player Win %": np.mean}),df.groupby('move1w').agg({"not_lose %": np.mean})
# Out:
# (          Player Win %
#  move1w
#  1.00E+03     32.300000
#  1.00E+04     39.000000
#  1.Nc3        37.980000
#  1.Nf3        34.600000
#  1.a3         35.700000
#  1.b3         34.400000
#  1.b4         39.663636
#  1.c3         32.300000
#  1.c4         32.134951
#  1.d3         39.000000
#  1.d4         34.273025
#  1.e4         36.125368
#  1.f4         38.540000
#  1.g3         29.075000
#  1.g4         44.850000
#  1.h3         36.600000
#  1.h4         33.900000,           not_lose %
#  move1w
#  1.00E+03   53.000000
#  1.00E+04   62.500000
#  1.Nc3      64.440000
#  1.Nf3      65.500000
#  1.a3       61.300000
#  1.b3       62.857143
#  1.b4       63.290909
#  1.c3       58.700000
#  1.c4       64.851456
#  1.d3       61.700000
#  1.d4       66.697411
#  1.e4       63.986632
#  1.f4       61.580000
#  1.g3       59.375000
#  1.g4       63.600000
#  1.h3       58.500000
#  1.h4       52.900000)

# %%
df[(df['move1w'] == '1.e4') & (df['move1b'] == "d6") ].groupby('move2w').head()
# Out:
#                                        Opening Colour  Num Games  ECO  \
# 206                     Czech Defense, General  black       7257  B07
# 654            King Pawn Game, Maroczy Defense  black        514  B07
# 803                Lion Defense, Anti-Philidor  white        113  B07
# 804   Lion Defense, Anti-Philidor, Lion's Cave  black        833  B07
# 805               Lion Defense, Bayonet Attack  white        259  B07
# 1233                    Rat Defense, Harmonist  white        795  B07
#
#      Last Played  Perf Rating  Avg Player  Player Win %  Draw %  \
# 206   2018-07-06         2154        2202          33.2    25.4
# 654   2018-05-31         2027        2081          28.2    31.9
# 803   2018-04-29         2177        2097          46.0    17.7
# 804   2018-06-28         2131        2184          32.4    23.6
# 805   2018-05-06         2382        2312          59.1    20.1
# 1233  2018-07-03         2171        2140          42.0    24.1
#
# ...

# %%
b1 = df[(df['move1w'] == '1.e4')].groupby('move1b')
#.agg({'move1b':np.count})
#.sort_values('Num Games', ascending = False)
b1.head()
# Out:
#                                                 Opening Colour  Num Games  \
# 0                    Alekhine Defense, Balogh Variation  white        692
# 1                  Alekhine Defense, Brooklyn Variation  black        228
# 2                  Alekhine Defense, Exchange Variation  white       6485
# 3                   Alekhine Defense, Four Pawns Attack  white        881
# 4     Alekhine Defense, Four Pawns Attack, Fianchett...  black        259
# 90                     Bishop's Opening, Berlin Defense  black       4006
# 91                      Bishop's Opening, Blanel Gambit  black        189
# 92           Bishop's Opening, Boden-Kieseritsky Gambit  white        322
# 93                      Bishop's Opening, Boi Variation  black        343
# 94                            Bishop's Opening, General  white        901
# 123         Caro-Kann Defense, Accelerated Panov Attack  white        644
# 124         Caro-Kann Defense, Accelerated Panov Attack  black        936
# ...
